# %%
import os
import urllib.request
import shutil
import re
import pandas as pd

# %%
pd.options.display.max_colwidth = 10000
pd.options.display.max_rows
pd.set_option('display.max_colwidth', -1)
pd.options.mode.chained_assignment = None  # default='warn'

# %%
url = "https://hackerspace.govhack.org/challenges.csv"

pattern = "[A-Z|a-z]*.csv$"
challenges_file_name = re.search(pattern, url).group()

if not os.path.isfile(challenges_file_name):
    # Download the file from `url` and save it locally under `file_name`:
    with urllib.request.urlopen(url) as response, open(challenges_file_name, 'wb') as out_file:
        shutil.copyfileobj(response, out_file)

# %%
challenges_dataframe = pd.read_csv(challenges_file_name, na_values=['.'])
display(challenges_dataframe)
# Out:
#                      region_name  competition_year   id  \
# 0   Australia                     2019              170
# 1   Australia                     2019              121
# 2   Australia                     2019              113
# 3   Australia                     2019              112
# 4   New Zealand                   2019              172
# 5   New Zealand                   2019              174
# 6   Tasmania                      2019              159
# 7   Tasmania                      2019              158
# 8   New Zealand                   2019              173
# 9   Australian Capital Territory  2019              127
# 10  Australian Capital Territory  2019              126
# 11  Australian Capital Territory  2019              128
# 12  Tasmania                      2019              162
# 13  New Zealand                   2019              124
# 14  Northern Territory            2019              177
# 15  Northern Territory            2019              155
# ...

# %%
display(challenges_dataframe.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 11 columns):
# region_name         75 non-null object
# competition_year    75 non-null int64
# id                  75 non-null int64
# name                75 non-null object
# short_desc          75 non-null object
# long_desc           63 non-null object
# eligibility         74 non-null object
# video_url           10 non-null object
# created_at          75 non-null object
# updated_at          75 non-null object
# sponsors            75 non-null object
# dtypes: int64(2), object(9)
# memory usage: 6.5+ KB
# None

# %%
display(challenges_dataframe.head())
# Out:
#    region_name  competition_year   id  \
# 0  Australia    2019              170
# 1  Australia    2019              121
# 2  Australia    2019              113
# 3  Australia    2019              112
# 4  New Zealand  2019              172
#
#                                                                          name  \
# 0  ATO for individuals
# 1  Australia@Sea: what is our future relationship with the ocean environment?
# 2  Australia’s Future Employment
# 3  Bankruptcy – making it easier
# 4  Best Creative Use Of Technology
#
#                                                                                                                                                                                                                                                                                                                                                                                                        short_desc  \
# ...

# %%
display(challenges_dataframe.loc[[0]])
# Out:
#   region_name  competition_year   id                 name  \
# 0  Australia   2019              170  ATO for individuals
#
#                                                                                                    short_desc  \
# 0  How can ATO and other Australian public data be used to help the community fill employment opportunities?
#
# ...

# %%
display(challenges_dataframe['region_name'].unique())
# Out:
# array(['Australia', 'New Zealand', 'Tasmania',
#        'Australian Capital Territory', 'Northern Territory', 'Victoria',
#        'South Australia', 'Queensland', 'Western Australia',
#        'New South Wales', 'International'], dtype=object)

# %%
allowed_challenges = ['Australia', 'Australian Capital Territory', 'International']
challenges_dataframe = challenges_dataframe[challenges_dataframe.region_name.isin(allowed_challenges)];
challenges_dataframe = challenges_dataframe.drop(columns=['competition_year', "created_at", "updated_at"]);

display(challenges_dataframe)
# Out:
#                      region_name   id  \
# 0   Australia                     170
# 1   Australia                     121
# 2   Australia                     113
# 3   Australia                     112
# 9   Australian Capital Territory  127
# 10  Australian Capital Territory  126
# 11  Australian Capital Territory  128
# 27  Australia                     110
# 28  Australia                     114
# 34  International                 109
# 37  Australia                     118
# 39  Australia                     119
# 48  International                 107
# 51  International                 108
# 52  Australia                     115
# 53  International                 106
# 63  Australia                     120
# 64  Australia                     122
# 65  Australia                     125
# 70  Australia                     117
# 71  Australia                     116
#
#                                                                            name  \
# 0   ATO for individuals
# ...

# %%
challenges_dataframe["Notes"] = "NA"
list(challenges_dataframe.columns.values)
# Out:
# ['region_name',
#  'id',
#  'name',
#  'short_desc',
#  'long_desc',
#  'eligibility',
#  'video_url',
#  'sponsors',
#  'Notes']

# %%
new_order = [8, 1,0,7,6,2,3,4,5]
challenges_dataframe = challenges_dataframe[challenges_dataframe.columns[new_order]]

# %%
pd.DataFrame(challenges_dataframe, index = [0])
# Out:
#   Notes   id region_name sponsors video_url                 name  \
# 0  NA    170  Australia   ["ATO"]  NaN       ATO for individuals
#
#                                                                                                    short_desc  \
# 0  How can ATO and other Australian public data be used to help the community fill employment opportunities?
#
# ...

# %%
#Add notes


challenges_dataframe.Notes[challenges_dataframe.id==119] = "linked to 119"
challenges_dataframe.Notes[challenges_dataframe.id==125] = "AI add human incentive - too subjective"

challenges_dataframe.Notes[challenges_dataframe.id==106] = "[traffic] infosys traffic cbd ai love it"
challenges_dataframe.Notes[challenges_dataframe.id==108] = "[traffic] aws traffic cbd ai love it"
challenges_dataframe.Notes[challenges_dataframe.id==115] = "Queensland API"
challenges_dataframe.Notes[challenges_dataframe.id==126] = "Fun stuff!!! connect ppl with env"
challenges_dataframe.Notes[challenges_dataframe.id==120] = "build resilience for people"


challenges_dataframe.Notes[challenges_dataframe.id==107] = "[not interested] infosys electric planning fun stuff real time monitering + weather conditions not avilible :("
challenges_dataframe.Notes[challenges_dataframe.id==110] = "[not interested] Too hard to generalise for so many different user groups! not solid! no domine knowladge! no idea about the pain points :("
challenges_dataframe.Notes[challenges_dataframe.id==116] = "[not interested] water monitering"
challenges_dataframe.Notes[challenges_dataframe.id==122] = "[not interested] closed source AI"

challenges_dataframe.Notes[challenges_dataframe.id==170] = "Find the industries that have grown in the past and try to find the types of jobs added to them and types of jobs subtracted and try to find the condition that leads to the creation of that businesses."
challenges_dataframe.Notes[challenges_dataframe.id==113] = "Linked to 170"
challenges_dataframe.Notes[challenges_dataframe.id==114] = "LOVE IT!! HOW TO SUPPORT SMALL BUSSINESS YASSSS"

# %%
#remove chanleges not intrested in 
challenges_dataframe = challenges_dataframe[challenges_dataframe.id != 121] # water
challenges_dataframe = challenges_dataframe[challenges_dataframe.id != 112] # bankcrupcy
challenges_dataframe = challenges_dataframe[challenges_dataframe.id != 128] # youth
challenges_dataframe = challenges_dataframe[challenges_dataframe.id != 127] # noobs
challenges_dataframe = challenges_dataframe[challenges_dataframe.id != 109] # plastic
challenges_dataframe = challenges_dataframe[challenges_dataframe.id != 118] # water
challenges_dataframe = challenges_dataframe[challenges_dataframe.id != 117] # water school

challenges_dataframe = challenges_dataframe[challenges_dataframe.id != 107] # not interested
challenges_dataframe = challenges_dataframe[challenges_dataframe.id != 110] # not interested
challenges_dataframe = challenges_dataframe[challenges_dataframe.id != 116] # not interested
challenges_dataframe = challenges_dataframe[challenges_dataframe.id != 122] # not interested

challenges_dataframe = challenges_dataframe[challenges_dataframe.id != 170] # interested but no time
challenges_dataframe = challenges_dataframe[challenges_dataframe.id != 113] # interested but no time
challenges_dataframe = challenges_dataframe[challenges_dataframe.id != 114] # interested but no time
challenges_dataframe = challenges_dataframe[challenges_dataframe.id != 125] # interested but no time

# %%
len(challenges_dataframe)
challenges_dataframe
# Out:
#                                                                                       Notes  \
# 10  Fun stuff!!! first get a baseline map soild dataset and then build a model on top of it
# 39  linked to 119
# 51  [traffic] aws traffic cbd ai love it
# 52  Queensland API
# 53  [traffic] infosys traffic cbd ai love it
# 63  Future OzOzOz
#
#      id                   region_name  \
# 10  126  Australian Capital Territory
# 39  119  Australia
# 51  108  International
# 52  115  Australia
# 53  106  International
# 63  120  Australia
#
#                                             sponsors  \
# 10  ["ACT Government"]
# 39  ["Department of Industry, Innovation & Science"]
# 51  ["Amazon Web Services"]
# 52  ["Queensland Government"]
# 53  ["Infosys"]
# 63  ["CSIRO"]
#
#                                     video_url  \
# 10  NaN
# 39  NaN
# 51  NaN
# 52  https://www.youtube.com/embed/3AZNqXeD4c4
# 53  NaN
# 63  NaN
#
#                                                              name  \
# ...
